# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 698

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?appid=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # The weather API gives Max Temp in Kelvin. Converting to fahrenheit 
        # formula: F = 1.8*(K-273) + 32.
        city_max_temp = (city_max_temp - 273.15)*1.8 + 32
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | general roca
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | dharmavaram
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | mogok
# Processing Record 13 of Set 1 | katsuura
# Processing Record 14 of Set 1 | codrington
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | kultuk
# Processing Record 17 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | quatre cocos
# Processing Record 20 of Set 1 | puerto leguizamo
# Processing Record 21 of Set 1 | bandar-e lengeh
# Processing Record 22 of Set 1 | hithadhoo
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | havoysund
# Processing Record 25 of Set 1 | sao francisco
# Processing Record 26 of Set 1 | pevek
# Processing Record 27 of Set 1 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 1 | semey
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | krasavino
# Processing Record 36 of Set 1 | omboue
# Processing Record 37 of Set 1 | miyako
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | kondinskoye
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | san blas
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | yulara
# Processing Record 48 of Set 1 | nevinnomyssk
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | ust-tsilma
# Processing Record 2 of Set 2 | namatanai
# Processing Record 3 of Set 2 | kahului
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | kurilsk
# Processing Record 6 of Set 2 | princeville
# Processing Record 7 of Set 2 | solvychegodsk
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | cheremshan
# Processing Record 11 of Set 2 | guerrero negro
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | myitkyina
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | abaza
# Processing Record 19 of Set 2 | samarai
# Processing Record 20 of Set 2 | mayor pablo lagerenza
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | tartagal
# Processing Record 24 of Set 2 | ranong
# Processing Record 25 of Set 2 | anadyr
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | sangar
# Processing Record 29 of Set 2 | hashtrud
# Processing Record 30 of Set 2 | jaramana
# City not found. Skipping...
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | zaranj
# Processing Record 33 of Set 2 | sibolga
# Processing Record 34 of Set 2 | talnakh
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | mogadishu
# Processing Record 37 of Set 2 | carutapera
# Processing Record 38 of Set 2 | matata
# Processing Record 39 of Set 2 | santana do livramento
# Processing Record 40 of Set 2 | kashmor
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | naze
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | croy
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | kaitangata
# Processing Record 48 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | kapoeta
# Processing Record 50 of Set 2 | poplar bluff
# Processing Record 1 of Set 3 | tiarei
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | meulaboh
# Processing Record 4 of Set 3 | puri
# Processing Record 5 of Set 3 | malinovskiy
# Processing Record 6 of Set 3 | esqueda
# Processing Record 7 of Set 3 | altay
# Processing Record 8 of Set 3 | pareora
# Processing Record 9 of Set 3 | agarak
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | gangakher
# Processing Record 12 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 3 | geraldton
# Processing Record 14 of Set 3 | hervey bay
# Processing Record 15 of Set 3 | alta gracia
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | olinda
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | sajanan
# Processing Record 23 of Set 3 | raahe
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | okhotsk
# Processing Record 26 of Set 3 | rovaniemi
# Processing Record 27 of Set 3 | santa cruz
# Processing Record 28 of Set 3 | sorland
# Processing Record 29 of Set 3 | nizhniy kuranakh
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | isla mujeres
# Processing Record 32 of Set 3 | cody
# Processing Record 33 of Set 3 | vanavara
# Processing Record 34 of Set 3 | constitucion
# Processing Record 35 of Set 3 | tezu
# Processing Record 36 of Set 3 | itaituba
# Processing Record 37 of Set 3 | ati
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | te anau
# Processing Record 40 of Set 3 | khilok
# Processing Record 41 of Set 3 | rohtak
# Processing Record 42 of Set 3 | nioro
# Processing Record 43 of Set 3 | gizo
# Processing Record 44 of Set 3 | lebu
# Processing Record 45 of Set 3 | weiser
# Processing Record 46 of Set 3 | buchanan
# Processing Record 47 of Set 3 | tahoua
# Processing Record 48 of Set 3 | bonoua
# Processing Record 49 of Set 3 | hobyo
# Processing Record 50 of Set 3 | lagoa
# Processing Record 1 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | yerbogachen
# Processing Record 4 of Set 4 | longyearbyen
# Processing Record 5 of Set 4 | maceio
# Processing Record 6 of Set 4 | rawson
# Processing Record 7 of Set 4 | itaueira
# Processing Record 8 of Set 4 | datong
# Processing Record 9 of Set 4 | provideniya
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | mana
# Processing Record 12 of Set 4 | nehe
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | lovozero
# Processing Record 15 of Set 4 | brae
# Processing Record 16 of Set 4 | bocas del toro
# Processing Record 17 of Set 4 | grand gaube
# Processing Record 18 of Set 4 | warrington
# Processing Record 19 of Set 4 | cabo san lucas
# Processing Record 20 of Set 4 | mukhen
# Processing Record 21 of Set 4 | biak
# Processing Record 22 of Set 4 | san quintin
# Processing Record 23 of Set 4 | broome
# Processing Record 24 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 4 | merauke
# Processing Record 26 of Set 4 | felanitx
# Processing Record 27 of Set 4 | vavoua
# Processing Record 28 of Set 4 | jinchang
# Processing Record 29 of Set 4 | ixtapa
# Processing Record 30 of Set 4 | ponta do sol
# Processing Record 31 of Set 4 | marathopolis
# City not found. Skipping...
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | songjianghe
# Processing Record 34 of Set 4 | burnie
# Processing Record 35 of Set 4 | shahrud
# Processing Record 36 of Set 4 | ust-kuyga
# Processing Record 37 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 4 | dire
# Processing Record 39 of Set 4 | clyde river
# Processing Record 40 of Set 4 | mahebourg
# Processing Record 41 of Set 4 | pisco
# Processing Record 42 of Set 4 | dzaoudzi
# Processing Record 43 of Set 4 | salinopolis
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | vigrestad
# Processing Record 46 of Set 4 | batagay
# Processing Record 47 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 4 | pontianak
# Processing Record 49 of Set 4 | katuli
# Processing Record 50 of Set 4 | stryn
# Processing Record 1 of Set 5 | calvinia
# Processing Record 2 of Set 5 | lata
# Processing Record 3 of Set 5 | korla
# Processing Record 4 of Set 5 | moree
# Processing Record 5 of Set 5 | hasaki
# Processing Record 6 of Set 5 | birjand
# Processing Record 7 of Set 5 | kushima
# Processing Record 8 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 9 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 10 of Set 5 | ilulissat
# Processing Record 11 of Set 5 | benguela
# Processing Record 12 of Set 5 | la asuncion
# Processing Record 13 of Set 5 | prince rupert
# Processing Record 14 of Set 5 | cidreira
# Processing Record 15 of Set 5 | arlit
# Processing Record 16 of Set 5 | saint-joseph
# Processing Record 17 of Set 5 | waddan
# Processing Record 18 of Set 5 | meinung
# City not found. Skipping...
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | umm kaddadah
# Processing Record 21 of Set 5 | mehamn
# Processing Record 22 of Set 5 | henties bay
# Processing Record 23 of Set 5 | tura
# Processing Record 24 of Set 5 | esperance
# Processing Record 25 of Set 5 | caravelas
# Processing Record 26 of Set 5 | grindavik
# Processing Record 27 of Set 5 | maisuru
# City not found. Skipping...
# Processing Record 28 of Set 5 | sitka
# Processing Record 29 of Set 5 | cam ranh
# Processing Record 30 of Set 5 | turukhansk
# Processing Record 31 of Set 5 | hastings
# Processing Record 32 of Set 5 | bathsheba
# Processing Record 33 of Set 5 | lac du bonnet
# Processing Record 34 of Set 5 | severo-kurilsk
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | college
# Processing Record 37 of Set 5 | upata
# Processing Record 38 of Set 5 | tual
# Processing Record 39 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 5 | ravar
# Processing Record 41 of Set 5 | saint-georges
# Processing Record 42 of Set 5 | adet
# Processing Record 43 of Set 5 | abu dhabi
# Processing Record 44 of Set 5 | ballstad
# City not found. Skipping...
# Processing Record 45 of Set 5 | chokwe
# Processing Record 46 of Set 5 | sambava
# Processing Record 47 of Set 5 | hami
# Processing Record 48 of Set 5 | notre-dame-du-lac
# Processing Record 49 of Set 5 | sao filipe
# Processing Record 50 of Set 5 | poum
# Processing Record 1 of Set 6 | tautira
# Processing Record 2 of Set 6 | coquimbo
# Processing Record 3 of Set 6 | dryden
# Processing Record 4 of Set 6 | limon
# Processing Record 5 of Set 6 | erdenet
# Processing Record 6 of Set 6 | brunsbuttel
# Processing Record 7 of Set 6 | tuatapere
# Processing Record 8 of Set 6 | torbay
# Processing Record 9 of Set 6 | kindu
# Processing Record 10 of Set 6 | westport
# Processing Record 11 of Set 6 | svay rieng
# Processing Record 12 of Set 6 | aykhal
# Processing Record 13 of Set 6 | marawi
# Processing Record 14 of Set 6 | kyra
# Processing Record 15 of Set 6 | vila velha
# Processing Record 16 of Set 6 | ancud
# Processing Record 17 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 6 | taltal
# Processing Record 19 of Set 6 | gillette
# Processing Record 20 of Set 6 | rurrenabaque
# Processing Record 21 of Set 6 | chany
# Processing Record 22 of Set 6 | zalesovo
# Processing Record 23 of Set 6 | nuuk
# Processing Record 24 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 6 | usinsk
# Processing Record 26 of Set 6 | samana
# Processing Record 27 of Set 6 | port blair
# Processing Record 28 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 6 | olafsvik
# Processing Record 30 of Set 6 | nizwa
# Processing Record 31 of Set 6 | dunedin
# Processing Record 32 of Set 6 | bella vista
# Processing Record 33 of Set 6 | terni
# Processing Record 34 of Set 6 | stornoway
# Processing Record 35 of Set 6 | sawakin
# Processing Record 36 of Set 6 | fortuna
# Processing Record 37 of Set 6 | colomi
# Processing Record 38 of Set 6 | praia
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | vardo
# Processing Record 41 of Set 6 | abatskoye
# Processing Record 42 of Set 6 | sri aman
# Processing Record 43 of Set 6 | roma
# Processing Record 44 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 6 | rab
# City not found. Skipping...
# Processing Record 46 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 6 | fuengirola
# Processing Record 48 of Set 6 | tome-acu
# City not found. Skipping...
# Processing Record 49 of Set 6 | diu
# Processing Record 50 of Set 6 | nha trang
# Processing Record 1 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 7 | la ronge
# Processing Record 3 of Set 7 | razole
# Processing Record 4 of Set 7 | manga
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | cururupu
# Processing Record 7 of Set 7 | maarianhamina
# Processing Record 8 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 7 | saskylakh
# Processing Record 10 of Set 7 | husavik
# Processing Record 11 of Set 7 | kargasok
# Processing Record 12 of Set 7 | convencion
# City not found. Skipping...
# Processing Record 13 of Set 7 | bambous virieux
# Processing Record 14 of Set 7 | cam pha
# City not found. Skipping...
# Processing Record 15 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 16 of Set 7 | rockhampton
# Processing Record 17 of Set 7 | opoczno
# Processing Record 18 of Set 7 | aksu
# Processing Record 19 of Set 7 | saint anthony
# Processing Record 20 of Set 7 | narsaq
# Processing Record 21 of Set 7 | kirakira
# Processing Record 22 of Set 7 | porterville
# Processing Record 23 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 7 | asau
# Processing Record 25 of Set 7 | priargunsk
# Processing Record 26 of Set 7 | carnarvon
# Processing Record 27 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 28 of Set 7 | ketchikan
# Processing Record 29 of Set 7 | cuamba
# Processing Record 30 of Set 7 | vostok
# Processing Record 31 of Set 7 | wajima
# Processing Record 32 of Set 7 | maripi
# Processing Record 33 of Set 7 | las palmas
# Processing Record 34 of Set 7 | airai
# Processing Record 35 of Set 7 | praia da vitoria
# Processing Record 36 of Set 7 | lufilufi
# Processing Record 37 of Set 7 | baillif
# Processing Record 38 of Set 7 | tacuati
# Processing Record 39 of Set 7 | carson city
# Processing Record 40 of Set 7 | alcala la real
# Processing Record 41 of Set 7 | ferkessedougou
# Processing Record 42 of Set 7 | whitianga
# Processing Record 43 of Set 7 | we
# City not found. Skipping...
# Processing Record 44 of Set 7 | ruteng
# Processing Record 45 of Set 7 | derzhavinsk
# Processing Record 46 of Set 7 | mastic beach
# Processing Record 47 of Set 7 | colesberg
# Processing Record 48 of Set 7 | lanxi
# Processing Record 49 of Set 7 | gambela
# Processing Record 50 of Set 7 | sompeta
# Processing Record 1 of Set 8 | krishnarajasagara
# Processing Record 2 of Set 8 | srivardhan
# Processing Record 3 of Set 8 | babayurt
# Processing Record 4 of Set 8 | carmen
# Processing Record 5 of Set 8 | bubaque
# Processing Record 6 of Set 8 | nouadhibou
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | san patricio
# Processing Record 9 of Set 8 | ilo
# Processing Record 10 of Set 8 | svetlogorsk
# Processing Record 11 of Set 8 | amapa
# Processing Record 12 of Set 8 | bluefields
# Processing Record 13 of Set 8 | saldanha
# Processing Record 14 of Set 8 | kudahuvadhoo
# Processing Record 15 of Set 8 | ahipara
# Processing Record 16 of Set 8 | cockburn town
# Processing Record 17 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 8 | grimari
# City not found. Skipping...
# Processing Record 19 of Set 8 | santa ana
# Processing Record 20 of Set 8 | wageningen
# Processing Record 21 of Set 8 | wajir
# Processing Record 22 of Set 8 | wanning
# Processing Record 23 of Set 8 | kholm
# Processing Record 24 of Set 8 | lloydminster
# Processing Record 25 of Set 8 | kaeo
# Processing Record 26 of Set 8 | burica
# City not found. Skipping...
# Processing Record 27 of Set 8 | pangoa
# Processing Record 28 of Set 8 | burgersdorp
# Processing Record 29 of Set 8 | buala
# Processing Record 30 of Set 8 | byron bay
# Processing Record 31 of Set 8 | bhitarwar
# Processing Record 32 of Set 8 | mpongwe
# Processing Record 33 of Set 8 | enterprise
# Processing Record 34 of Set 8 | surt
# Processing Record 35 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 36 of Set 8 | negombo
# Processing Record 37 of Set 8 | luderitz
# Processing Record 38 of Set 8 | mount isa
# Processing Record 39 of Set 8 | cabedelo
# Processing Record 40 of Set 8 | sao joao da barra
# Processing Record 41 of Set 8 | comarapa
# Processing Record 42 of Set 8 | astana
# Processing Record 43 of Set 8 | harnosand
# Processing Record 44 of Set 8 | les cayes
# Processing Record 45 of Set 8 | bud
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | maniitsoq
# Processing Record 48 of Set 8 | duz
# City not found. Skipping...
# Processing Record 49 of Set 8 | togur
# Processing Record 50 of Set 8 | dabhol
# Processing Record 1 of Set 9 | vuktyl
# Processing Record 2 of Set 9 | karmala
# Processing Record 3 of Set 9 | fairbanks
# Processing Record 4 of Set 9 | pembroke
# Processing Record 5 of Set 9 | the valley
# Processing Record 6 of Set 9 | policoro
# Processing Record 7 of Set 9 | rio grande
# Processing Record 8 of Set 9 | suhbaatar
# Processing Record 9 of Set 9 | ipixuna
# Processing Record 10 of Set 9 | hambantota
# Processing Record 11 of Set 9 | abu samrah
# Processing Record 12 of Set 9 | saint-paul
# Processing Record 13 of Set 9 | ossora
# Processing Record 14 of Set 9 | nelson bay
# Processing Record 15 of Set 9 | pundaguitan
# Processing Record 16 of Set 9 | beringovskiy
# Processing Record 17 of Set 9 | sao jose da coroa grande
# Processing Record 18 of Set 9 | liku
# Processing Record 19 of Set 9 | hamilton
# Processing Record 20 of Set 9 | andenes
# Processing Record 21 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 9 | palauig
# Processing Record 24 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 9 | coihaique
# Processing Record 26 of Set 9 | troitskoye
# Processing Record 27 of Set 9 | ryazanovskiy
# Processing Record 28 of Set 9 | konstanz
# Processing Record 29 of Set 9 | russkiy
# Processing Record 30 of Set 9 | trincomalee
# Processing Record 31 of Set 9 | lavrentiya
# Processing Record 32 of Set 9 | rudnogorsk
# Processing Record 33 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 34 of Set 9 | tiszadob
# Processing Record 35 of Set 9 | ambilobe
# Processing Record 36 of Set 9 | ferme-neuve
# Processing Record 37 of Set 9 | kavaratti
# Processing Record 38 of Set 9 | callaway
# Processing Record 39 of Set 9 | ariquemes
# Processing Record 40 of Set 9 | aklavik
# Processing Record 41 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 9 | atherton
# Processing Record 43 of Set 9 | qandala
# Processing Record 44 of Set 9 | betioky
# Processing Record 45 of Set 9 | huron
# Processing Record 46 of Set 9 | muli
# Processing Record 47 of Set 9 | atar
# Processing Record 48 of Set 9 | victoria
# Processing Record 49 of Set 9 | ballina
# Processing Record 50 of Set 9 | soure
# Processing Record 1 of Set 10 | coahuayana
# Processing Record 2 of Set 10 | mizque
# Processing Record 3 of Set 10 | brekstad
# Processing Record 4 of Set 10 | sabha
# Processing Record 5 of Set 10 | ust-shonosha
# Processing Record 6 of Set 10 | baruun-urt
# Processing Record 7 of Set 10 | oxford
# Processing Record 8 of Set 10 | kedrovyy
# Processing Record 9 of Set 10 | fatsa
# Processing Record 10 of Set 10 | tabuk
# Processing Record 11 of Set 10 | bandarbeyla
# Processing Record 12 of Set 10 | goure
# Processing Record 13 of Set 10 | fort nelson
# Processing Record 14 of Set 10 | karsava
# Processing Record 15 of Set 10 | vilyuysk
# Processing Record 16 of Set 10 | janauba
# Processing Record 17 of Set 10 | isangel
# Processing Record 18 of Set 10 | kathmandu
# Processing Record 19 of Set 10 | owando
# Processing Record 20 of Set 10 | trois-pistoles
# City not found. Skipping...
# Processing Record 21 of Set 10 | igarka
# Processing Record 22 of Set 10 | tuburan
# Processing Record 23 of Set 10 | nishihara
# Processing Record 24 of Set 10 | cortes
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | puerto suarez
# Processing Record 27 of Set 10 | georgiyevka
# Processing Record 28 of Set 10 | sisimiut
# Processing Record 29 of Set 10 | chitral
# Processing Record 30 of Set 10 | leningradskiy
# Processing Record 31 of Set 10 | sur
# Processing Record 32 of Set 10 | launceston
# Processing Record 33 of Set 10 | evensk
# Processing Record 34 of Set 10 | farafangana
# Processing Record 35 of Set 10 | northam
# Processing Record 36 of Set 10 | cambyreta
# City not found. Skipping...
# Processing Record 37 of Set 10 | sioux lookout
# Processing Record 38 of Set 10 | otofuke
# Processing Record 39 of Set 10 | georgetown
# Processing Record 40 of Set 10 | port hardy
# Processing Record 41 of Set 10 | odweyne
# Processing Record 42 of Set 10 | ghanzi
# Processing Record 43 of Set 10 | knyaze-volkonskoye
# Processing Record 44 of Set 10 | acapulco
# Processing Record 45 of Set 10 | nantucket
# Processing Record 46 of Set 10 | amahai
# Processing Record 47 of Set 10 | nur
# Processing Record 48 of Set 10 | coruripe
# Processing Record 49 of Set 10 | tutoia
# Processing Record 50 of Set 10 | allapalli
# Processing Record 1 of Set 11 | moose factory
# Processing Record 2 of Set 11 | san juan
# Processing Record 3 of Set 11 | prince george
# Processing Record 4 of Set 11 | adrar
# Processing Record 5 of Set 11 | gweta
# Processing Record 6 of Set 11 | kamogawa
# Processing Record 7 of Set 11 | cortez
# Processing Record 8 of Set 11 | yinchuan
# Processing Record 9 of Set 11 | samfya
# Processing Record 10 of Set 11 | pasni
# Processing Record 11 of Set 11 | williams lake
# Processing Record 12 of Set 11 | nurota
# Processing Record 13 of Set 11 | visnes
# Processing Record 14 of Set 11 | iralaya
# Processing Record 15 of Set 11 | libreville
# Processing Record 16 of Set 11 | talara
# Processing Record 17 of Set 11 | tianpeng
# Processing Record 18 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 11 | duartina
# Processing Record 20 of Set 11 | shishou
# Processing Record 21 of Set 11 | vila
# Processing Record 22 of Set 11 | salalah
# Processing Record 23 of Set 11 | tamworth
# Processing Record 24 of Set 11 | bukan
# Processing Record 25 of Set 11 | koygorodok
# Processing Record 26 of Set 11 | stephenville crossing
# Processing Record 27 of Set 11 | floresti
# Processing Record 28 of Set 11 | cardston
# Processing Record 29 of Set 11 | kibaya
# Processing Record 30 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 11 | jalu
# Processing Record 32 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 11 | terney
# Processing Record 34 of Set 11 | nogales
# Processing Record 35 of Set 11 | pangkalanbuun
# Processing Record 36 of Set 11 | kitimat
# Processing Record 37 of Set 11 | maba
# Processing Record 38 of Set 11 | fonte boa
# Processing Record 39 of Set 11 | pimentel
# Processing Record 40 of Set 11 | kamina
# Processing Record 41 of Set 11 | necochea
# Processing Record 42 of Set 11 | batsfjord
# Processing Record 43 of Set 11 | suluq
# Processing Record 44 of Set 11 | nemuro
# Processing Record 45 of Set 11 | shingu
# Processing Record 46 of Set 11 | saint-augustin
# Processing Record 47 of Set 11 | benjamin constant
# Processing Record 48 of Set 11 | jieshi
# Processing Record 49 of Set 11 | san luis
# Processing Record 50 of Set 11 | shemgang
# Processing Record 1 of Set 12 | nome
# Processing Record 2 of Set 12 | kieta
# Processing Record 3 of Set 12 | quelimane
# Processing Record 4 of Set 12 | camacha
# Processing Record 5 of Set 12 | wadi musa
# Processing Record 6 of Set 12 | volchikha
# Processing Record 7 of Set 12 | namibe
# Processing Record 8 of Set 12 | hoquiam
# Processing Record 9 of Set 12 | klaksvik
# Processing Record 10 of Set 12 | namalenga
# Processing Record 11 of Set 12 | kusk
# City not found. Skipping...
# Processing Record 12 of Set 12 | yining
# Processing Record 13 of Set 12 | vangaindrano
# Processing Record 14 of Set 12 | bilma
# Processing Record 15 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 16 of Set 12 | jingdezhen
# Processing Record 17 of Set 12 | santo antonio do ica
# Processing Record 18 of Set 12 | korem
# Processing Record 19 of Set 12 | kalmunai
# Processing Record 20 of Set 12 | anloga
# Processing Record 21 of Set 12 | lander
# Processing Record 22 of Set 12 | champerico
# Processing Record 23 of Set 12 | sasd
# Processing Record 24 of Set 12 | chuy
# Processing Record 25 of Set 12 | emerald
# Processing Record 26 of Set 12 | ellisras
# Processing Record 27 of Set 12 | mecca
# Processing Record 28 of Set 12 | dubti
# Processing Record 29 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 12 | almaznyy
# Processing Record 31 of Set 12 | langenburg
# Processing Record 32 of Set 12 | dicabisagan
# Processing Record 33 of Set 12 | hauterive
# Processing Record 34 of Set 12 | kruisfontein
# Processing Record 35 of Set 12 | butembo
# Processing Record 36 of Set 12 | gedo
# Processing Record 37 of Set 12 | chapais
# Processing Record 38 of Set 12 | touliu
# City not found. Skipping...
# Processing Record 39 of Set 12 | pangnirtung
# Processing Record 40 of Set 12 | sohag
# Processing Record 41 of Set 12 | llanes
# Processing Record 42 of Set 12 | povenets
# Processing Record 43 of Set 12 | beisfjord
# Processing Record 44 of Set 12 | am timan
# Processing Record 45 of Set 12 | tucupita
# Processing Record 46 of Set 12 | aswan
# Processing Record 47 of Set 12 | amazar
# Processing Record 48 of Set 12 | nizhniy odes
# Processing Record 49 of Set 12 | faya
# Processing Record 50 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 1 of Set 13 | pawai
# Processing Record 2 of Set 13 | deputatskiy
# Processing Record 3 of Set 13 | mongo
# Processing Record 4 of Set 13 | port-cartier
# Processing Record 5 of Set 13 | hilton head island
# Processing Record 6 of Set 13 | longonjo
# Processing Record 7 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 13 | portland
# Processing Record 9 of Set 13 | chaman
# Processing Record 10 of Set 13 | jinan
# Processing Record 11 of Set 13 | morondava
# Processing Record 12 of Set 13 | healdsburg
# Processing Record 13 of Set 13 | benghazi
# Processing Record 14 of Set 13 | weligama
# Processing Record 15 of Set 13 | lichinga
# Processing Record 16 of Set 13 | margate
# Processing Record 17 of Set 13 | bardstown
# Processing Record 18 of Set 13 | liverpool
# Processing Record 19 of Set 13 | uniara
# Processing Record 20 of Set 13 | spanish town
# Processing Record 21 of Set 13 | ahvaz
# Processing Record 22 of Set 13 | goderich
# Processing Record 23 of Set 13 | french harbor
# Processing Record 24 of Set 13 | honningsvag
# Processing Record 25 of Set 13 | carroll
# Processing Record 26 of Set 13 | sabang
# Processing Record 27 of Set 13 | beira
# Processing Record 28 of Set 13 | galle
# Processing Record 29 of Set 13 | grande-synthe
# Processing Record 30 of Set 13 | andros town
# Processing Record 31 of Set 13 | howard springs
# Processing Record 32 of Set 13 | ulladulla
# Processing Record 33 of Set 13 | gamba
# Processing Record 34 of Set 13 | agde
# Processing Record 35 of Set 13 | talesh
# City not found. Skipping...
# Processing Record 36 of Set 13 | mirnyy
# Processing Record 37 of Set 13 | hirara
# Processing Record 38 of Set 13 | akdepe
# Processing Record 39 of Set 13 | areosa
# Processing Record 40 of Set 13 | zyryanka
# Processing Record 41 of Set 13 | poya
# Processing Record 42 of Set 13 | ayame
# Processing Record 43 of Set 13 | bellingham
# Processing Record 44 of Set 13 | severobaykalsk
# Processing Record 45 of Set 13 | pochutla
# Processing Record 46 of Set 13 | bustonkala
# City not found. Skipping...
# Processing Record 47 of Set 13 | ewa beach
# Processing Record 48 of Set 13 | manokwari
# Processing Record 49 of Set 13 | lazaro cardenas
# Processing Record 50 of Set 13 | coos bay
# Processing Record 1 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 14 | labuhan
# Processing Record 4 of Set 14 | sechura
# Processing Record 5 of Set 14 | muzhi
# Processing Record 6 of Set 14 | krasnoselkup
# Processing Record 7 of Set 14 | tirumala
# Processing Record 8 of Set 14 | bhanpuri
# Processing Record 9 of Set 14 | teguise
# Processing Record 10 of Set 14 | camargo
# Processing Record 11 of Set 14 | chaoyang
# Processing Record 12 of Set 14 | urumqi
# Processing Record 13 of Set 14 | vestmannaeyjar
# Processing Record 14 of Set 14 | kommunisticheskiy
# Processing Record 15 of Set 14 | beloha
# Processing Record 16 of Set 14 | viedma
# Processing Record 17 of Set 14 | manica
# Processing Record 18 of Set 14 | tateyama
# Processing Record 19 of Set 14 | miles city
# Processing Record 20 of Set 14 | koumac
# Processing Record 21 of Set 14 | rorvik
# Processing Record 22 of Set 14 | aktau
# Processing Record 23 of Set 14 | chernyshevskiy
# Processing Record 24 of Set 14 | springfield
# Processing Record 25 of Set 14 | yajalon
# Processing Record 26 of Set 14 | inuvik
# Processing Record 27 of Set 14 | beinamar
# Processing Record 28 of Set 14 | sept-iles
# Processing Record 29 of Set 14 | riyadh
# Processing Record 30 of Set 14 | kenai
# Processing Record 31 of Set 14 | burns lake
# Processing Record 32 of Set 14 | pocao de pedras
# Processing Record 33 of Set 14 | praya
# Processing Record 34 of Set 14 | ngunguru
# Processing Record 35 of Set 14 | sistranda
# Processing Record 36 of Set 14 | trinidad
# Processing Record 37 of Set 14 | capreol
# Processing Record 38 of Set 14 | khonsa
# Processing Record 39 of Set 14 | apache junction
# Processing Record 40 of Set 14 | rambha
# Processing Record 41 of Set 14 | guozhen
# Processing Record 42 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 14 | rio claro
# Processing Record 44 of Set 14 | paita
# Processing Record 45 of Set 14 | jasper
# Processing Record 46 of Set 14 | havre
# Processing Record 47 of Set 14 | gouyave
# Processing Record 48 of Set 14 | tatsuno
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df["Max Temp"] = round(city_data_df["Max Temp"], 2)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     General Roca      AR -39.0333  -67.5833     66.36        15          28
# 1          Mataura      NZ -46.1927  168.8643     46.13        95          98
# 2           Albany      US  42.6001  -73.9662     41.88        85         100
# 3      Dharmavaram      IN  14.4333   77.7167     84.00        32          92
# 4          Rikitea      PF -23.1203 -134.9692     76.71        66          56
# 5         Hermanus      ZA -34.4187   19.2345     61.81        87           1
# 6          Ushuaia      AR -54.8000  -68.3000     38.86        81          40
# 7  Arraial Do Cabo      BR -22.9661  -42.0278     82.36        74          40
# 8   Ribeira Grande      PT  38.5167  -28.7000     64.80        63          20
# 9        Cape Town      ZA -33.9258   18.4232     65.12        80           0
#
#    Wind Speed Current Description
# 0        9.36    scattered clouds
# 1        0.90     overcast clouds
# 2        0.92       moderate rain
# 3        1.39     overcast clouds
# 4        4.59       broken clouds
# 5        3.84           clear sky
# 6       13.89          light rain
# 7        5.66    scattered clouds
# 8        4.63          few clouds
# 9        6.17           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
